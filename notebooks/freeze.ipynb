# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pylab as plt

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(20.7,8.27)})

# %%
from pdkit.gait_time_series import GaitTimeSeries
from pdkit.gait_processor import GaitProcessor
from pdkit.utils import butter_lowpass_filter

# %%
import scipy.signal as sig
import pywt

# %%
freeze_data = '/src/data/pdkit/dataset_fog_release/dataset/S01R01.txt'
gd = GaitTimeSeries.load_data(freeze_data, format_file='freeze')
# Out:
# Sampling rate is 64.0 samples / second

# %%
gd[['x', 'y', 'z']].plot()

# %%
gp = GaitProcessor(sampling_frequency=64.0, filter_order=4, cutoff_frequency=2.0)

# %%
plt.plot(butter_lowpass_filter(gd.x, sample_rate=64.0, cutoff=2, order=4))
