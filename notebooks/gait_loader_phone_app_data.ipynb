# %%
from pdkit.gait_time_series import GaitTimeSeries
from pdkit.gait_processor import GaitProcessor
# Out:
# /home/c/lab/envs/pdkit/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import pandas as pd
import numpy as np

# %%
ts = GaitTimeSeries.load_data('../tests/data/cloudupdrs_gait.csv')

# %%
ts.head()
# Out:
#                                   td          x         y         z  \
# 1970-01-01 00:00:00.000000  0.000000  10.038197  0.694638 -0.299648
# 1970-01-01 00:00:00.024536  0.024536   9.888372  0.694638 -0.272407
# 1970-01-01 00:00:00.042755  0.042755   9.915613  0.653777 -0.272407
# 1970-01-01 00:00:00.060761  0.060761   9.915613  0.612916 -0.299648
# 1970-01-01 00:00:00.078766  0.078766   9.915613  0.612916 -0.231546
#
#                             mag_sum_acc
# 1970-01-01 00:00:00.000000    10.066663
# 1970-01-01 00:00:00.024536     9.916483
# 1970-01-01 00:00:00.042755     9.940876
# 1970-01-01 00:00:00.060761     9.939056
# 1970-01-01 00:00:00.078766     9.937236

# %%
convert_times=1000000000.0
filename = '/home/c/data/pdkit/acc/lcd-up.tsv'

data_m = np.genfromtxt(filename, delimiter='\t', invalid_raise=False)
date_times = pd.to_datetime((data_m[:, 0] - data_m[0, 0]))
time_difference = (data_m[:, 0] - data_m[0, 0]) / convert_times
magnitude_sum_acceleration = \
    np.sqrt(data_m[:, 1] ** 2 + data_m[:, 2] ** 2 + data_m[:, 3] ** 2)
data = {'td': time_difference, 'x': data_m[:, 1], 'y': data_m[:, 2], 'z': data_m[:, 3],
        'mag_sum_acc': magnitude_sum_acceleration}
data_frame = pd.DataFrame(data, index=date_times, columns=['td', 'x', 'y', 'z', 'mag_sum_acc'])

# %%
data_m.shape
# Out:
# (3999, 6)

# %%
df = pd.read_csv(filename, sep='\t', header=None)
df.drop(columns=[0, 5], inplace=True)
df.columns = ['td', 'x', 'y', 'z']
df.td = (df.td - df.td[0])
df.index = pd.to_datetime(df.td * 10000000)
df.td = df.td / 100.
del df.index.name
df['mag_sum_acc'] = np.sqrt(df.x ** 2 + df.y ** 2 + df.z ** 2)
df
# Out:
#                              td      x      y       z  mag_sum_acc
# 1970-01-01 00:00:00.000    0.00  0.261  0.495   9.821     9.836930
# 1970-01-01 00:00:00.040    0.04  0.235  0.507   9.909     9.924745
# 1970-01-01 00:00:00.080    0.08  0.215  0.479   9.914     9.927893
# 1970-01-01 00:00:00.130    0.13  0.244  0.479   9.983     9.997463
# 1970-01-01 00:00:00.180    0.18  0.268  0.462   9.986    10.000273
# 1970-01-01 00:00:00.230    0.23  0.294  0.474   9.950     9.965622
# 1970-01-01 00:00:00.280    0.28  0.306  0.445   9.916     9.930696
# 1970-01-01 00:00:00.330    0.33  0.285  0.438   9.883     9.896805
# 1970-01-01 00:00:00.380    0.38  0.294  0.457   9.835     9.850001
# 1970-01-01 00:00:00.430    0.43  0.297  0.443   9.828     9.842461
# 1970-01-01 00:00:00.480    0.48  0.318  0.433   9.789     9.803731
# 1970-01-01 00:03:21.610  201.61  0.254  0.606   7.900     7.927279
# 1970-01-01 00:03:21.650  201.65 -0.184  0.579   8.861     8.881803
# 1970-01-01 00:03:21.710  201.71 -0.357  1.049   9.584     9.647845
# 1970-01-01 00:03:21.760  201.76 -0.218  1.159  10.192    10.260003
# 1970-01-01 00:03:21.810  201.81  0.077  0.991  10.836    10.881494
# 1970-01-01 00:03:21.860  201.86  0.390  0.891  11.255    11.296947
# 1970-01-01 00:03:21.910  201.91  0.649  0.809  11.324    11.371396
# 1970-01-01 00:03:21.960  201.96  0.852  0.742  11.176    11.232962
# 1970-01-01 00:03:22.010  202.01  0.989  0.776  10.975    11.046761
# 1970-01-01 00:03:22.060  202.06  1.041  0.819  10.642    10.724113
# 1970-01-01 00:03:22.110  202.11  0.881  0.883  10.242    10.317675
# 1970-01-01 00:03:22.160  202.16  0.615  0.982   9.868     9.935793
#
# [3999 rows x 5 columns]

# %%
df.time - df.time[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d3849658323c> in <module>()
# ----> 1 df.time - df.time[0]
#
# ~/lab/envs/pdkit/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'time'

# %%
df.index.values#[:, 0] - df.index.values[0, 0]
# Out:
# array(['1970-01-01T00:00:00.000000000', '1970-01-01T00:00:00.040000000',
#        '1970-01-01T00:00:00.080000000', ...,
#        '1970-01-01T00:03:22.060000000', '1970-01-01T00:03:22.110000000',
#        '1970-01-01T00:03:22.160000000'], dtype='datetime64[ns]')

# %%
df.rename(columns={'time': 'td'}, inplace=True)

# %%
df['mag_sum_acc'] = np.sqrt(df.x ** 2 + df.y ** 2 + df.z ** 2)

# %%
df.index = df.td * 1000000000.0

# %%
df.index = pd.to_timedelta(df.index.values)

# %%
df
# Out:
#                     td     x     y     z  mag_sum_acc
# 00:00:00.006000  0.006 -0.06  0.27 -0.80     0.846463
# 00:00:00.007000  0.007  0.04  0.27 -1.09     1.123655
# 00:00:00.011000  0.011  0.01  0.21 -1.26     1.277419
# 00:00:00.017000  0.017 -0.00  0.18 -1.32     1.332216
# 00:00:00.025000  0.025 -0.06  0.18 -1.32     1.333567
# 00:00:00.035000  0.035 -0.14  0.16 -1.23     1.248239
# 00:00:00.035000  0.035 -0.17  0.18 -1.06     1.088531
# 00:00:00.037000  0.037 -0.24  0.13 -0.83     0.873728
# 00:00:00.042000  0.042 -0.34  0.08 -0.55     0.651537
# 00:00:00.068000  0.068 -0.39  0.04 -0.25     0.464973
# 00:00:00.069000  0.069 -0.34  0.04 -0.01     0.342491
# 00:00:00.069000  0.069 -0.24  0.03  0.25     0.347851
# 00:00:00.069000  0.069 -0.18 -0.01  0.40     0.438748
# 00:00:00.069000  0.069 -0.08 -0.07  0.45     0.462385
# 00:00:00.081000  0.081 -0.03 -0.10  0.46     0.471699
# 00:00:00.082000  0.082 -0.00 -0.09  0.46     0.468722
# 00:00:00.095000  0.095  0.02 -0.09  0.39     0.400749
# 00:00:00.095000  0.095  0.04 -0.09  0.27     0.287402
