# %%
import pdkit
import pandas as pd
# Out:
# /Users/juansaez/Code/test_pdkit/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv('./tests/data/cussp_dataframe.csv')
df
# Out:
#       id  LA-LL-amplitude_by_fft  LA-LL-frequency_by_fft  \
# 0   2458                0.906875                4.687500
# 1   3573                1.014563                3.125000
# 2   2459                1.452961                2.734375
# 3   3048                5.369214                5.468750
# 4   3009                0.348179                3.515625
# 5   3486                0.978712                3.515625
# 6   3018                0.035288                3.515625
# 7   2505                5.537679                2.734375
# 8   2675               10.580257                3.515625
# 9   2678                1.712184                3.906250
# 10  2679                4.161566                2.734375
# 11  2815                0.023778                4.687500
# 12  3493                0.978712                3.515625
# 13  3552                0.885084                3.906250
# 14  2656                3.546834                1.953125
# ...

# %%
cp = pdkit.ClusterProcessor(df)
cp.process()

# %%
centroids = cp.get_centroids_by_observation('LA-LL')

# %%
sd = cp.get_sd_by_observation('LA-LL')

# %%
cl = pdk.Classification(centroids, sd)

# %%
point = cp.get_features_for_observation('LA-LL')[7,:-1]

# %%
cl.classify(point)

# %%
cl.nearest_cluster
# Out:
# 0
